# %%
import pandas as pd
from pandas import DataFrame
from pylab import *
import matplotlib.pyplot as pt
# %matplotlib inline

#I learned that I have to have all of the above executed before anything below will work i.e. 
#import pandas as pd  
#from pandas import DataFrame
#from pylab import *  This means everything from pylab
#import matplotlib.pyplot as pt
#%matplotlib inline  See page 30 of textbook

# %%
kickstart = pd.read_csv('C:/Users/User/Documents/Data Science Course Materials/ks-projects-201801.csv',index_col='ID', 
                        encoding='utf-8', sep=",")  
#After many tries, I discovered that I must have the full file path to locate my file. 
#I could not rename my column headings in this code
#I could only indicate the Index Column...and the rest of what you see above
#I also learned that if in the top right there is a message about ...Connecting or Not Connecting, I have to reboot my computer

# %%
kickstart.head()
# Out:
#                                                          name        category  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah          Poetry
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#            main_category currency   deadline     goal         launched  \
# ID
# 1000002330    Publishing      GBP  10/9/2015   1000.0  8/11/2015 12:12
# 1000003930  Film & Video      USD  11/1/2017  30000.0    9/2/2017 4:43
# 1000004038  Film & Video      USD  2/26/2013  45000.0   1/12/2013 0:20
# 1000007540         Music      USD  4/16/2012   5000.0   3/17/2012 3:24
# 1000011046  Film & Video      USD  8/29/2015  19500.0    7/4/2015 8:35
#
# ...

# %%
# First, I want to change backers to backer, because per SQL best practice a variable name is singular
pt.plot(kickstart['backers'])
show()

# %%
country = kickstart['country']
country_count = country.value_counts()
country_count #Below we want to clean out or transform the N,0" below which don't appear to be a real country
# Out:
# US      292627
# GB       33672
# CA       14756
# AU        7839
# DE        4171
# N,0"      3797
# FR        2939
# IT        2878
# NL        2868
# ES        2276
# SE        1757
# MX        1752
# NZ        1447
# DK        1113
# IE         811
# CH         761
# NO         708
# HK         618
# BE         617
# AT         597
# SG         555
# LU          62
# JP          40
# Name: country, dtype: int64

# %%
main_category=kickstart['main_category']
main_category_count = main_category.value_counts()
main_category_count #Below we want to clean
# Out:
# Film & Video    63585
# Music           51918
# Publishing      39874
# Games           35231
# Technology      32569
# Design          30070
# Art             28153
# Food            24602
# Fashion         22816
# Theater         10913
# Comics          10819
# Photography     10779
# Crafts           8809
# Journalism       4755
# Dance            3768
# Name: main_category, dtype: int64

# %%
currency=kickstart['currency']
currency_count = currency.value_counts()
currency_count #Below we want to clean
# Out:
# USD    295365
# GBP     34132
# EUR     17405
# CAD     14962
# AUD      7950
# SEK      1788
# MXN      1752
# NZD      1475
# DKK      1129
# CHF       768
# NOK       722
# HKD       618
# SGD       555
# JPY        40
# Name: currency, dtype: int64

# %%
kickstart.head()  #Seems I still can't rename backers as backer in the dataframe ??
# Out:
#                                                          name        category  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah          Poetry
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#            main_category currency   deadline     goal         launched  \
# ID
# 1000002330    Publishing      GBP  10/9/2015   1000.0  8/11/2015 12:12
# 1000003930  Film & Video      USD  11/1/2017  30000.0    9/2/2017 4:43
# 1000004038  Film & Video      USD  2/26/2013  45000.0   1/12/2013 0:20
# 1000007540         Music      USD  4/16/2012   5000.0   3/17/2012 3:24
# 1000011046  Film & Video      USD  8/29/2015  19500.0    7/4/2015 8:35
#
# ...

# %%
kickstart.category  #Now I want to explore the variables to get a feel for the data

# %%
kickstart.main_category
# Out:
# ID
# 1000002330      Publishing
# 1000003930    Film & Video
# 1000004038    Film & Video
# 1000007540           Music
# 1000011046    Film & Video
# 1000014025            Food
# 1000023410            Food
# 1000030581            Food
# 1000034518          Design
# 100004195     Film & Video
# 100004721       Publishing
# 100005484            Music
# 1000055792          Crafts
# 1000056157           Games
# 1000057089           Games
# 1000064368          Design
# 1000064918          Comics
# 1000068480      Publishing
# 1000070642           Music
# 1000071625            Food
# 1000072011         Fashion
# 1000081649         Fashion
# 1000082254         Theater
# 1000087442            Food
# 1000091520          Comics
# 1000102741           Music
# 1000103948          Crafts
# 1000104688    Film & Video
# 1000104953          Comics
# 100011318     Film & Video
#                   ...
# 999832803            Games
# 99984851      Film & Video
# 999865831          Fashion
# ...

# %%
kickstart.name
# Out:
# ID
# 1000002330                      The Songs of Adelaide & Abullah
# 1000003930        Greeting From Earth: ZGAC Arts Capsule For ET
# 1000004038                                       Where is Hank?
# 1000007540    ToshiCapital Rekordz Needs Help to Complete Album
# 1000011046    Community Film Project: The Art of Neighborhoo...
# 1000014025                                 Monarch Espresso Bar
# 1000023410    Support Solar Roasted Coffee & Green Energy!  ...
# 1000030581    Chaser Strips. Our Strips make Shots their B*tch!
# 1000034518    SPIN - Premium Retractable In-Ear Headphones w...
# 100004195     STUDIO IN THE SKY - A Documentary Feature Film...
# 100004721                                   Of Jesus and Madmen
# 100005484                                      Lisa Lim New CD!
# 1000055792                                   The Cottage Market
# 1000056157    G-Spot Place for Gamers to connect with eachot...
# 1000057089    Tombstone: Old West tabletop game and miniatur...
# ...

# %%
kickstart.currency
# Out:
# ID
# 1000002330    GBP
# 1000003930    USD
# 1000004038    USD
# 1000007540    USD
# 1000011046    USD
# 1000014025    USD
# 1000023410    USD
# 1000030581    USD
# 1000034518    USD
# 100004195     USD
# 100004721     CAD
# 100005484     USD
# 1000055792    USD
# 1000056157    USD
# 1000057089    GBP
# 1000064368    USD
# 1000064918    USD
# 1000068480    USD
# 1000070642    USD
# 1000071625    USD
# 1000072011    USD
# 1000081649    AUD
# 1000082254    USD
# 1000087442    NOK
# 1000091520    USD
# 1000102741    USD
# 1000103948    GBP
# 1000104688    CAD
# 1000104953    GBP
# 100011318     USD
#              ...
# 999832803     USD
# 99984851      USD
# 999865831     USD
# 999867839     USD
# 99987261      USD
# 999877902     CAD
# 999878813     USD
# 999880710     USD
# 999884445     USD
# 999893629     USD
# 99991751      CHF
# 999929142     EUR
# 999931480     USD
# 999934908     USD
# 999941823     GBP
# 999943841     USD
# 999950812     USD
# 999955533     USD
# ...

# %%
kickstart.deadline
# Out:
# ID
# 1000002330     10/9/2015
# 1000003930     11/1/2017
# 1000004038     2/26/2013
# 1000007540     4/16/2012
# 1000011046     8/29/2015
# 1000014025      4/1/2016
# 1000023410    12/21/2014
# 1000030581     3/17/2016
# 1000034518     5/29/2014
# 100004195      8/10/2014
# 100004721      10/9/2013
# 100005484       4/8/2013
# 1000055792     10/2/2014
# 1000056157     3/25/2016
# 1000057089      5/3/2017
# 1000064368     2/28/2015
# 1000064918     11/8/2014
# 1000068480     5/10/2015
# 1000070642     8/17/2012
# 1000071625      6/2/2012
# 1000072011    12/30/2013
# 1000081649      9/7/2017
# 1000082254     6/15/2014
# 1000087442     2/25/2015
# 1000091520    11/12/2014
# 1000102741      1/6/2011
# 1000103948      1/5/2016
# 1000104688    12/14/2014
# 1000104953     1/28/2016
# 100011318       5/3/2017
#                  ...
# 999832803      10/3/2014
# 99984851        6/5/2014
# 999865831     12/13/2014
# 999867839       1/8/2011
# 99987261       9/24/2015
# 999877902     12/17/2014
# ...

# %%
kickstart.goal
# Out:
# ID
# 1000002330      1000.0
# 1000003930     30000.0
# 1000004038     45000.0
# 1000007540      5000.0
# 1000011046     19500.0
# 1000014025     50000.0
# 1000023410      1000.0
# 1000030581     25000.0
# 1000034518    125000.0
# 100004195      65000.0
# 100004721       2500.0
# 100005484      12500.0
# 1000055792      5000.0
# 1000056157    200000.0
# 1000057089      5000.0
# 1000064368      2500.0
# 1000064918      1500.0
# 1000068480      3000.0
# 1000070642       250.0
# 1000071625      5000.0
# 1000072011     20000.0
# 1000081649      2500.0
# 1000082254      3500.0
# 1000087442       500.0
# 1000091520       175.0
# 1000102741     10000.0
# 1000103948     12000.0
# 1000104688     17757.0
# 1000104953       100.0
# 100011318      50000.0
#                 ...
# 999832803      10000.0
# 99984851       12000.0
# 999865831      25000.0
# 999867839       4000.0
# 99987261         800.0
# 999877902       5000.0
# 999878813      10000.0
# 999880710       5000.0
# ...

# %%
kickstart.goal.sum() #The sum for goal is over $18 Billion
# Out:
# 18584981597.970005

# %%
kickstart.goal.mean() #The mean for goal is $49 thousand
# Out:
# 49080.79152056854

# %%
kickstart.goal.max() #The max for goal is $100 Million
# Out:
# 100000000.0

# %%
kickstart.goal.min() #The min for goal is 1 cent
# Out:
# 0.01

# %%
kickstart.goal.describe() #This is faster but a little hard to digest given the notation
# Out:
# count    3.786610e+05
# mean     4.908079e+04
# std      1.183391e+06
# min      1.000000e-02
# 25%      2.000000e+03
# 50%      5.200000e+03
# 75%      1.600000e+04
# max      1.000000e+08
# Name: goal, dtype: float64

# %%
kickstart.usd_goal_real.describe()
# Out:
# count    3.786610e+05
# mean     4.545440e+04
# std      1.152950e+06
# min      1.000000e-02
# 25%      2.000000e+03
# 50%      5.500000e+03
# 75%      1.550000e+04
# max      1.663614e+08
# Name: usd_goal_real, dtype: float64

# %%
kickstart.usd_pledged_real.describe()
# Out:
# count    3.786610e+05
# mean     9.058924e+03
# std      9.097334e+04
# min      0.000000e+00
# 25%      3.100000e+01
# 50%      6.243300e+02
# 75%      4.050000e+03
# max      2.033899e+07
# Name: usd_pledged_real, dtype: float64

# %%
kickstart.launched
# Out:
# ID
# 1000002330     8/11/2015 12:12
# 1000003930       9/2/2017 4:43
# 1000004038      1/12/2013 0:20
# 1000007540      3/17/2012 3:24
# 1000011046       7/4/2015 8:35
# 1000014025     2/26/2016 13:38
# 1000023410     12/1/2014 18:30
# 1000030581      2/1/2016 20:05
# 1000034518     4/24/2014 18:14
# 100004195      7/11/2014 21:55
# 100004721       9/9/2013 18:19
# 100005484        3/9/2013 6:42
# 1000055792      9/2/2014 17:11
# 1000056157      2/9/2016 23:01
# 1000057089      4/5/2017 19:44
# 1000064368      1/29/2015 2:10
# 1000064918     10/9/2014 22:27
# 1000068480     4/10/2015 21:20
# 1000070642      8/2/2012 14:11
# 1000071625      5/3/2012 17:24
# 1000072011     11/25/2013 7:06
# 1000081649       8/8/2017 1:20
# 1000082254     5/16/2014 10:10
# 1000087442     1/26/2015 19:17
# 1000091520    10/23/2014 17:15
# 1000102741     12/7/2010 23:16
# 1000103948     12/6/2015 20:09
# 1000104688    11/14/2014 18:02
# 1000104953    12/29/2015 16:59
# 100011318       4/3/2017 17:11
# ...

# %%
kickstart.pledged
# Out:
# ID
# 1000002330        0.00
# 1000003930     2421.00
# 1000004038      220.00
# 1000007540        1.00
# 1000011046     1283.00
# 1000014025    52375.00
# 1000023410     1205.00
# 1000030581      453.00
# 1000034518     8233.00
# 100004195      6240.57
# 100004721         0.00
# 100005484     12700.00
# 1000055792        0.00
# 1000056157        0.00
# 1000057089    94175.00
# 1000064368      664.00
# 1000064918      395.00
# 1000068480      789.00
# 1000070642      250.00
# 1000071625     1781.00
# 1000072011    34268.00
# 1000081649        1.00
# 1000082254      650.00
# 1000087442       48.00
# 1000091520      701.66
# 1000102741    15827.00
# 1000103948        0.00
# 1000104688    48905.00
# 1000104953      112.38
# 100011318     57577.31
#                 ...
# 999832803     13861.50
# 99984851          0.00
# 999865831     11643.00
# 999867839      3531.00
# 99987261         70.00
# 999877902      5435.00
# 999878813     10245.00
# 999880710        18.00
# ...

# %%
kickstart.state
# Out:
# ID
# 1000002330        failed
# 1000003930        failed
# 1000004038        failed
# 1000007540        failed
# 1000011046      canceled
# 1000014025    successful
# 1000023410    successful
# 1000030581        failed
# 1000034518      canceled
# 100004195       canceled
# 100004721         failed
# 100005484     successful
# 1000055792        failed
# 1000056157        failed
# 1000057089    successful
# 1000064368        failed
# 1000064918        failed
# 1000068480        failed
# 1000070642    successful
# 1000071625        failed
# 1000072011    successful
# 1000081649        failed
# 1000082254        failed
# 1000087442        failed
# 1000091520    successful
# 1000102741    successful
# 1000103948        failed
# 1000104688    successful
# 1000104953    successful
# 100011318     successful
#                  ...
# 999832803     successful
# 99984851          failed
# 999865831         failed
# 999867839         failed
# 99987261          failed
# 999877902     successful
# ...

# %%
kickstart.backers
# Out:
# ID
# 1000002330      0
# 1000003930     15
# 1000004038      3
# 1000007540      1
# 1000011046     14
# 1000014025    224
# 1000023410     16
# 1000030581     40
# 1000034518     58
# 100004195      43
# 100004721       0
# 100005484     100
# 1000055792      0
# 1000056157      0
# 1000057089    761
# 1000064368     11
# 1000064918     16
# 1000068480     20
# 1000070642      7
# 1000071625     40
# 1000072011    624
# 1000081649      1
# 1000082254     12
# 1000087442      3
# 1000091520     66
# 1000102741    147
# 1000103948      0
# 1000104688    571
# 1000104953     27
# 100011318     840
#              ...
# 999832803     413
# 99984851        0
# 999865831      97
# 999867839      37
# 99987261        5
# 999877902      78
# 999878813     123
# 999880710       5
# 999884445     103
# 999893629       2
# 99991751        0
# 999929142      35
# 999931480       0
# 999934908     120
# 999941823      38
# 999943841      31
# 999950812      16
# 999955533       5
# ...

# %%
kickstart.country

# %%
kickstart.country
# Out:
# ID
# 1000002330    GB
# 1000003930    US
# 1000004038    US
# 1000007540    US
# 1000011046    US
# 1000014025    US
# 1000023410    US
# 1000030581    US
# 1000034518    US
# 100004195     US
# 100004721     CA
# 100005484     US
# 1000055792    US
# 1000056157    US
# 1000057089    GB
# 1000064368    US
# 1000064918    US
# 1000068480    US
# 1000070642    US
# 1000071625    US
# 1000072011    US
# 1000081649    AU
# 1000082254    US
# 1000087442    NO
# 1000091520    US
# 1000102741    US
# 1000103948    GB
# 1000104688    CA
# 1000104953    GB
# 100011318     US
#               ..
# 999832803     US
# 99984851      US
# 999865831     US
# 999867839     US
# 99987261      US
# 999877902     CA
# 999878813     US
# 999880710     US
# 999884445     US
# 999893629     US
# 99991751      CH
# 999929142     FR
# 999931480     US
# 999934908     US
# 999941823     GB
# 999943841     US
# 999950812     US
# 999955533     US
# 999963618     US
# 99996661      US
# 999969812     CA
# ...

# %%
kickstart.usd_pledged
# Out:
# ID
# 1000002330        0.00
# 1000003930      100.00
# 1000004038      220.00
# 1000007540        1.00
# 1000011046     1283.00
# 1000014025    52375.00
# 1000023410     1205.00
# 1000030581      453.00
# 1000034518     8233.00
# 100004195      6240.57
# 100004721         0.00
# 100005484     12700.00
# 1000055792        0.00
# 1000056157        0.00
# 1000057089    57763.78
# 1000064368      664.00
# 1000064918      395.00
# 1000068480      789.00
# 1000070642      250.00
# 1000071625     1781.00
# 1000072011    34268.00
# 1000081649        0.00
# 1000082254      650.00
# 1000087442        6.18
# 1000091520      701.66
# 1000102741    15827.00
# 1000103948        0.00
# 1000104688    43203.25
# 1000104953      167.70
# 100011318     10120.00
#                 ...
# 999832803     13861.50
# 99984851          0.00
# 999865831     11643.00
# 999867839      3531.00
# 99987261         70.00
# 999877902      4814.88
# 999878813       145.00
# 999880710        18.00
# ...

# %%
kickstart.usd_pledged_real
# Out:
# ID
# 1000002330         0.00
# 1000003930      2421.00
# 1000004038       220.00
# 1000007540         1.00
# 1000011046      1283.00
# 1000014025     52375.00
# 1000023410      1205.00
# 1000030581       453.00
# 1000034518      8233.00
# 100004195       6240.57
# 100004721          0.00
# 100005484      12700.00
# 1000055792         0.00
# 1000056157         0.00
# 1000057089    121857.33
# 1000064368       664.00
# 1000064918       395.00
# 1000068480       789.00
# 1000070642       250.00
# 1000071625      1781.00
# 1000072011     34268.00
# 1000081649         0.81
# 1000082254       650.00
# 1000087442         6.29
# 1000091520       701.66
# 1000102741     15827.00
# 1000103948         0.00
# 1000104688     42174.03
# 1000104953       160.60
# 100011318      57577.31
#                 ...
# 999832803      13861.50
# 99984851           0.00
# 999865831      11643.00
# 999867839       3531.00
# 99987261          70.00
# 999877902       4686.96
# 999878813      10245.00
# ...

# %%
kickstart.usd_goal_real
# Out:
# ID
# 1000002330      1533.95
# 1000003930     30000.00
# 1000004038     45000.00
# 1000007540      5000.00
# 1000011046     19500.00
# 1000014025     50000.00
# 1000023410      1000.00
# 1000030581     25000.00
# 1000034518    125000.00
# 100004195      65000.00
# 100004721       2406.39
# 100005484      12500.00
# 1000055792      5000.00
# 1000056157    200000.00
# 1000057089      6469.73
# 1000064368      2500.00
# 1000064918      1500.00
# 1000068480      3000.00
# 1000070642       250.00
# 1000071625      5000.00
# 1000072011     20000.00
# 1000081649      2026.10
# 1000082254      3500.00
# 1000087442        65.55
# 1000091520       175.00
# 1000102741     10000.00
# 1000103948     17489.65
# 1000104688     15313.04
# 1000104953       142.91
# 100011318      50000.00
#                 ...
# 999832803      10000.00
# 99984851       12000.00
# 999865831      25000.00
# 999867839       4000.00
# 99987261         800.00
# 999877902       4311.83
# 999878813      10000.00
# ...

# %%
import pandas as pd
from pandas import DataFrame
from pylab import *
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
kickstart = pd.read_csv('C:/Users/User/Documents/Data Science Course Materials/ks-projects-201801.csv',index_col='ID', 
                        encoding='utf-8', sep=",")

# %%
kickstart.head()
# Out:
#                                                          name        category  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah          Poetry
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#            main_category currency   deadline     goal         launched  \
# ID
# 1000002330    Publishing      GBP  10/9/2015   1000.0  8/11/2015 12:12
# 1000003930  Film & Video      USD  11/1/2017  30000.0    9/2/2017 4:43
# 1000004038  Film & Video      USD  2/26/2013  45000.0   1/12/2013 0:20
# 1000007540         Music      USD  4/16/2012   5000.0   3/17/2012 3:24
# 1000011046  Film & Video      USD  8/29/2015  19500.0    7/4/2015 8:35
#
# ...

# %%
#Let's say I wanted to now create a new dataframe with new columns and some omitted columns from original

kickstartrev = pd.DataFrame(kickstart, columns=['name', 'category', 'main_category', 'currency', 'launched', 'deadline', 
                                               'state', 'backers', 'country', 'usd_pledged_real', 'usd_goal_real', 'launch_year', 
                                               'launch_month', 'deadline_year', 'dealine_month'])

# %%
kickstartrev.head() #This worked.  Note that I should not repeat the index_col='ID', 
                        #encoding='utf-8', sep=",")
# Out:
#                                                          name        category  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah          Poetry
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#            main_category currency         launched   deadline     state  \
# ID
# 1000002330    Publishing      GBP  8/11/2015 12:12  10/9/2015    failed
# 1000003930  Film & Video      USD    9/2/2017 4:43  11/1/2017    failed
# 1000004038  Film & Video      USD   1/12/2013 0:20  2/26/2013    failed
# 1000007540         Music      USD   3/17/2012 3:24  4/16/2012    failed
# 1000011046  Film & Video      USD    7/4/2015 8:35  8/29/2015  canceled
#
# ...

# %%
kickstart.head()

# %%
#This is enough for tonight.  In the days ahead I will figure out how to fill those empty variables/columns I just created

# Let's plot all columns on a single chart

kickstartrev.plot(figsize=(25, 20))  #This works but plot is not useful; need to determine x and y axis most useful

# %%
kickstartrev['backers'].plot(figsize=(15, 5)) #This plot doesn't look right. I was hoping to see variation in backers by ID
